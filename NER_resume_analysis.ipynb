# %% [markdown]
# # **Building Resume Analysis Using Named Entity Recognition (NER)**
#
# The steps detailed in this [DataCamp article by Adib Ali Anwan](https://www.datacamp.com/blog/what-is-named-entity-recognition-ner) were used as a guide build this model.
#
#
# We will create a system for analyzing resumes that helps hiring managers filter candidates based on their skills and attributes.

# %% [markdown]
# ## **Install and Import Libraries**
#
# We import the required packages and initialize the spaCy model and WordNet Lemmatizer for later use.

# %%
# !pip install pyLDAvis
# !pip install PyPDF2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.11.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (3.1.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.10.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (1.2.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (4.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pyLDAvis) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.4.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->pyLDAvis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->pyLDAvis) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)

# %%
import spacy
import pyLDAvis
import wordcloud
import plotly
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download NLTK resources
nltk.download('stopwords')
nltk.download('wordnet')

# Load spaCy model
nlp = spacy.load('en_core_web_sm')

# Initialize WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## **Convert PDF to CSV**
#
# We convert resumes from PDF format into a CSV file, you can use various libraries in Python. One popular library for extracting text from PDFs is PyPDF2. Here's a basic approach to convert PDF resumes into a CSV file:
# * We define a function extract_text_from_pdf that takes a PDF file path as input and returns the extracted text from the PDF.
# * We iterate over each PDF file path in the pdf_files list, extract text from each PDF using the extract_text_from_pdf function, and store the text in a list.
# * We create a DataFrame data with columns 'ID' (to uniquely identify each resume) and 'resume_text' (to store the extracted text from resumes).
# * Finally, we save the DataFrame to a CSV file named 'resumes.csv'.

# %%
import PyPDF2
import pandas as pd

def extract_text_from_pdf(pdf_path):
    text = ''
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        for page in reader.pages:
            text += page.extract_text()
    return text

# List of PDF file paths containing resumes
pdf_files = ['/content/drive/MyDrive/Documents/CV & Applications/IME_INYANG_CV_.pdf',
             '/content/drive/MyDrive/Documents/CV & Applications/IME INYANG CV_bitnine.pdf',
             '/content/drive/MyDrive/Documents/CV & Applications/IME INYANG JR_CV.pdf',
             '/content/drive/MyDrive/Documents/CV & Applications/IME_INYANG_CV_BUA FOODS.pdf',
             '/content/drive/MyDrive/Documents/CV & Applications/IME_INYANG_IOM_CV (graphic design_data viz).pdf']

# Extract text from each PDF resume and store it in a list
resumes_text = [extract_text_from_pdf(pdf_path) for pdf_path in pdf_files]

# Create a DataFrame with columns 'ID' and 'resume_text'
data = pd.DataFrame({'ID': range(1, len(pdf_files)+1), 'resume_text': resumes_text})

# Save the DataFrame to a CSV file
data.to_csv('resumes.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## **Loading the Data and NER model**
#
# Here, the CSV file has three columns: `'ID'`, `'resume_text'`, and `'category'`.

# %%
# Load data from CSV file
data = pd.read_csv('resumes.csv')  # Replace 'resumes.csv' with the path to your CSV file
# Assuming your CSV file has columns named 'ID', 'resume_text', and 'category'

# Load spaCy model
nlp = spacy.load('en_core_web_sm')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## **Entity Ruler**
# Let's add an entity ruler pipeline to the spaCy model and create an entity ruler using a JSON file containing labels and patterns for skills:
#
# * We import EntityRuler from the `spacy.pipeline` module.
# * We import `json` module.
# * We add an entity ruler pipeline to the spaCy model using the `add_pipe` method.
# * We specify the position of the entity ruler pipeline using the `before` parameter to ensure it runs before the Named Entity Recognition (NER) pipeline.
# * We load `patterns` from a JSON file named `'skills_patterns.json'`, which contains labels and patterns for skills such as ".net", "cloud", and "aws".
# * We convert the JSON content to a Python dictionary.
# * We add the patterns to the entity ruler using the `add_patterns` method.

# %%
from spacy.pipeline import EntityRuler
# import json

# Add entity ruler pipeline to spaCy model
ruler = nlp.add_pipe("entity_ruler", before="ner")

# Load patterns from JSON file
# with open('skills_patterns.json', 'r') as file:
#     patterns = file.read()

# # Convert JSON to dictionary
# patterns = json.loads(patterns)

# Define patterns as dictionaries
patterns = [
    {"label": "SKILL", "pattern": [{"LOWER": "matplotlib"}]},
    {"label": "SKILL", "pattern": [{"LOWER": "python"}]},
    {"label": "SKILL", "pattern": [{"LOWER": "pandas"}]},
    {"label": "SKILL", "pattern": [{"LOWER": "seaborn"}]}
    # {"label": "PERSON", "pattern": [{"LOWER": "ime inyang"}]}
]

# Add patterns to entity ruler
ruler.add_patterns(patterns)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## **Text Cleaning**
# Let's clean the text data using NLTK following the steps you mentioned:
#
# * We define a function clean_text that takes a text input and performs the cleaning steps you mentioned.
# * We use regular expressions to remove hyperlinks, special characters, and punctuations.
# * We convert the text to lowercase and tokenize it into words.
# * We lemmatize each word to its base form using the WordNet Lemmatizer.
# * We remove English stop words using NLTK's stopwords corpus.
# * Finally, we apply this cleaning function to the 'resume_text' column in the DataFrame and store the cleaned text in a new column called 'cleaned_resume'.

# %%
import nltk
nltk.download('punkt')  # Download the 'punkt' tokenizer resource

import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Initialize WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    # Remove hyperlinks, special characters, and punctuations using regex
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^\w\s]', '', text)

    # Convert the text to lowercase
    text = text.lower()

    # Tokenize the text using nltk's word_tokenize
    words = word_tokenize(text)

    # Lemmatize the text to its base form for normalization
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

    # Remove English stop words
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in lemmatized_words if word not in stop_words]

    return filtered_words

# Clean the 'resume_text' column in the DataFrame
data['cleaned_resume'] = data['resume_text'].apply(clean_text)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## **Entity Recognition: Visualizing Named Entities in Text with `spaCy`**
# Next:
#
# * We import the displacy module from spaCy.
# * We define options for visualization, specifying the entity labels we want to display and their corresponding colors.
# * We loop through each resume text in the DataFrame.
# * We process each resume text with the spaCy model to obtain a Doc object.
# * We use displacy.render to visualize the named entities in the text with their labels highlighted. We set `jupyter=True` to display the visualization in a Jupyter notebook.
#
# This will display the named entities for each resume text with their respective labels highlighted.

# %%
from spacy import displacy

# Define options for visualization
# options = {'ents': ['PERSON', 'ORG', 'GPE', 'SKILL'], 'colors': {'PERSON': 'orange', 'ORG': 'yellow', 'GPE': 'lightgreen', 'SKILL': 'lightblue'}}
options = {'ents': ['PERSON', 'GPE', 'SKILL'], 'colors': {'PERSON': 'orange', 'GPE': 'lightgreen', 'SKILL': 'lightblue'}}

# Visualize named entities in each resume
for resume_text in data['resume_text']:
    doc = nlp(resume_text)
    displacy.render(doc, style="ent", jupyter=True, options=options)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> <br> <br>  <br>CONTACT  <br>alfiinyang@gmail.com  <br>+234 708 005 5637  <br>
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Port Harcourt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nigeria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br>PROFILES /PORTFOLIOS  <br>• DataCamp  <br>• Medium  <br>• LinkedIn  <br>• Canva  <br> <br>SKILLS  <br>•
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ,
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  <br>(CentOS7)  <br>• Graphic Design (Canva)  <br>• Public Speaking, Teaching,  <br>Technical Presentation  <br>• Excel, Power BI, <br>PowerPoint
# • ETL, Data Visualization, <br>(
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matplotlib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , <br>Numpy ,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seaborn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# )  <br>• Workplace Psychological <br>Safety, Cultural Intelligence , <br>Hypothesis based problem <br>solving  <br>INTERESTS  &amp; HOBBIES
# • Machine Learning and <br>Genomics
# • Marvel Comics  by Comics <br>Explained  <br>• Baseball 9  <br> Ime Inyang  <br>Data Scientist  <br> <br> <br>SUMMARY  <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  -oriented, organized and meticulous data scientist and enthusiastic team <br>player. Well -versed in statistical analysis techniques for insight derivation and <br>actively seeking opportunities to motivate others towards professional <br>development . Eager to continue growing in knowledge and applying skills to <br>real-world problems, especially in the health sector.  <br>EDUCATION  &amp; RELEVANT COURSEWORK  <br>Master of Data Science: Data Science   Sept  2024  – Sept  2026  <br>University of Guelph,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br>• Continuing education in Machine Learning for Sequential Data <br>Processing, Analysis of Spatial -Temporal Data, Neural Networks,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Multi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  -<br>Agent Systems  <br>Data Scientist Associate Certification   Jan 2023 – Present   <br>DataCamp  <br>• Completed professional development in Data Manipulation with <br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Data Visualization with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matplotlib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#   and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seaborn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  , Joining Data <br>with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Programming , and Statistics in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  . <br>• Continuing education in EDA with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Supervised learning with <br>
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scikit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  -learn, Unsupervised learning in P ython, Machine learning with <br>Tree -based models in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#   <br>Intro. to Software Project Management   Aug 20
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ime Okon Inyang Jnr.  <br>+234 708 005 5637  <br>alfiinyang@gmail.com  | github.com/alfiinyang/  <br> <br>Highlights of Qualifications
# • Bachelor of Engineering in Telecommunication Engineering  <br>• Experienced using Power BI for data modelling and visualization  <br>• Experienced using
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# 's  Numpy,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matplotlib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  , and Dat etime  packages  for <br>data analysis and machine learning preprocessing . <br>• Programs proficiently  in
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . <br>• Experienced using SQL to query databases (university level experience ). <br>• Over 6 months’ experience in
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  systems and storage administration for seismic <br>data processing.  <br>• Presentation, communication, and teaching skills practiced continuously through <br>business k nowledge sharing (C++ training  and business bids ). <br>• Problem -solving  and workplace psychological safety practice skills  gained through <br>2022 McKinsey Forward  training.  <br>Education  <br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  for Data Science        Jan 2023 – Present  <br>DataCamp  <br>Diploma in Software Project Management     Aug 2022 – Present  <br>National Programme on Technology Enhanced Learning (NPTEL),
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (Alison.com)  <br>Bachelor of Engineering  (Telecommunication  Engineering)  Nov. 2011 – April 2016  <br>Regent University College of Science and Technology,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ghana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   (Second Class Upper)  <br>• Project Title : Design and Construction of a Silent Home Security System Using Haptic <br>Technology ( 69% or B) <br>Work Experience  <br>Software Development Engineer / IT Support     Jun 2022 – Present  <br>NNPC ENSERV  (formerly IDSL) , Eleme PetroChemica l, Eleme, Rivers, Nigeria
# • Test s seismic data processing modules for proprietary software . <br>• Understudies  C++ source code for proprietary seismic data processing software.  <br>• Manage s
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  storage systems (tape -based) for seismic data processing , including <br>maintaining storage environment and managing backup activities.  <br>• Support s and maintain s
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  systems  and servers  for seismic data processing ,  <br>• Monitors and reports equipment health using Excel Spreadsheet.  <br>• Maintain s LAN/WLAN services for internet connectivity.  <br>• Monitors equipment health and reports to Systems Engineer . <br>Data Acquisition  Engineer        April 2018 – May 2022  <br>Integrated Data Services Ltd (IDSL),  36 Ogba Road, Ogogugbo,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benin City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Nigeria  <br>• Utilized Excel to track and visualize  employee work progress.  • Conducted leakage and SMT tests on ground sensors (geophones) using voltmeters <br>and SMT -300 devices to ascertain fit -for-purpose sensors.  <br>• Maintained and repaired data acqui sition instruments, including DT-HP305V  <br>geophones for seismic data acquisition in swampy terrain.  <br>• Installed and m aintained communication equipment for remote field workers . <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     • Researched
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and d eliver ed technical presentations on alternative  support processes <br>and technologies to aid  cost -effective  and high -quality  data acquisition projects.  <br>• Reported to Head of Engineering.  <br>Mathematics Teacher        Dec 2016 – Oct 2017  <br>Institute of Qur’anic Studies, Funtu a (formerly Imam Sc. &amp; Arts Secondary School)  <br>• Prepared lecture notes according to outlined curriculum.  <br>• Conducted continuous assessment tests for students and delivered assignments.  <br>• Corrected student assignments.  <br>• Recorded marks and reported to Vice
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Principa l.
# • Conducted
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  extra -moral classes to prepare Olympiad  mathematics candidates.  <br>Engineering Intern         Jul 2014 – Sept 2014  <br>Cross River Broadcasting Corp. (CRBC),
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">  <br> - 1 - IME OKON INYANG (JNR) 5 Ebo Road, off Airport Road,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benin City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nigeria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  +234 708 005 5637 (Mobile), alfiinyang@gmail.com (e-mail)  _______________________________________________________________________ PERSONAL INFORMATION Marital Status:  Single Nationality:  Nigerian Date of Birth:  17th December 1993 Languages:  English, Ibibio,
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Efik
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#   OBJECTIVES  • To support the transitioning of oil and gas related services originating in developing nations into first world markets through delivery of professional experience with safety consciousness, whilst adapting to new business systems and techniques.  • To provide professional training for the immediate generation of “interprofessional” and “transprofessional” oil and gas employees by organizing modular courses in related/experienced fields.  WORK EXPERIENCE Ministry of Science and Technology, Uyo, Akwa Ibom State, Nigeria Position:
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Attachee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (Engineering)    (August – September 2013) Responsibilities: • Purchasing electrical supplies • Assistance with technical labour  Cross River Broadcasting Corp. (CRBC),
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Calabar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Cross River State, Nigeria Position:
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Attachee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (Engineering)    (July – August 2014) Responsibilities: • Operational equipment maintenance and repair • Outside-Broadcast (O/B) equipment setup • Purchasing engineering supplies • Software usage assistance      <br> - 2 - Imam Science and Arts Secondary School,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Funtua
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Katsina State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Nigeria Position: NYSC Corper (Mathematics Teacher)  (December 2016 – October 2017) Responsibilities: • Teaching Senior Secondary 1 (SS1) students Mathematics • Conducting Mathematics Continuous Assessment Tests and Final Examination for SS1 students • Representing Corp Members serving in the institution to the school’s management Achievements: • Conducted free holiday Mathematics classes for students (COWBELLPEDIA competition)  NDLEA/NYSC Drug Free Club,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Funtua
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Katsina State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Nigeria Position: General Secretary    (February — November 2017) Responsibilities: • Record keeping of every meeting or event, conducted or organized within or by the club. • Preparation and delivery of documents and letters. • Organizing meetings with interest persons for club advancement. • Purchase of items for club's Community Development Project. Achievement: • Encouraged intercultural and interreligious symbiosis through sports and games, and open-air events.
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     • Co-led
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  community development project: contributed and sought funding for project, as well as purchased project completion items. o Developed system for increasing drug-abuse awareness using digital LED Display.
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nigeria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Christian Corpers Fellowship (NCCF) Funtua Zone, Katsina Chapter Position: Zonal Evangelism Secretary  (February — November 2017) Responsibilities: • Provide spiritual and moral encouragement for Christian corpers within Funtua Zone Achievement: • Helped establish new subzones within Funtua Zone and reestablished defunct subzones.   <br> - 3 -  Integrated Data Services Ltd. (IDSL),
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Edo State, Nigeria Position: Instrument Engineer   (April 2018 – October 2018) Responsibilities: • Maintenance of recording/acquisition equipment.  Position: Seismic Observer (Junior)    (October 2018 – January 2019) Responsibilities: • Line workers enrollment • Line workers job monitoring Achievements: • Developed swift process for staff monitoring and reporting using MS Excel and
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Word
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .  Position: Node-man (Offshore)    (January 2019 – December 2019) Respon
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> <br> <br>  Ime Inyang Jr.  <br>Data Scientist  / Software Developer
#
#
# SUMMARY  <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  -oriented, organized and meticulous data scientist and enthusiastic team <br>player. Well -versed in statistical analysis techniques  for product  development <br>and actively seeking opportunities to develop skills in machine learning. Eager <br>to continue growing in knowledge and applying skills to real -world problems, <br>especially in the food and  health industry . <br>EDUCATION  &amp; RELEVANT COURSEWORK  <br>Data Scientist Associate Certification                Jan 2023 – Present   <br>DataCamp  <br>• Received 1 -Year DataCamp Scholarship worth $200 from Data
# Scientists Network (DSN).  <br>• Completed professional development in Data Manipulation with <br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Data Visualization with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matplotlib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Joining Data with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , <br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Programming , and Statistics in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  . <br>• Continuing education in Data Visualization with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seaborn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , EDA with <br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Supervised learning with
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scikit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  -learn, Unsupervised learning in <br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Machine learning with
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tree
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  -based models in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#   <br>Intro. to Software Project Management   Aug 2022 – Jan 2023  <br>Alison.com  <br>• Completed professional development in concepts and characteristics <br>of software management, activities involved in software project <br>management, Project management standards, Software life cycle <br>models, AGILE models.  <br>Telecommunication Engineering (B.Eng)                 Nov. 2011 – April 2016  <br>Regent University College of Science and Technology,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ghana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br>(Second Class Upper)  <br>• Continued  education in
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and MATLA B <br>WORK HISTORY  <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Software Dev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  . Engineer / IT Support Specialist  May 2022 – Present  <br>NNPC ENSERV ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Port Harcourt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nigeria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br>• Contributed ideas and suggestions in team meetings and delivered <br>updates on deadlines, designs, and enhancements.  <br>• Discussed issues with team members to provide resolution and apply <br>best practices.  <br>• Participated in software field testing to verify performance of <br>developed projects.  <br>• Manages Linux storage systems (tape -based) for seismic data <br>processing, including maintaining storage environme nt and <br>managing backup activities.  <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     • Supports
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and maintains
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> <br> <br>  Ime Inyang  <br>Data Scientist  / Graphic Designer  <br> <br> <br>SUMMARY  <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  -oriented, organized and meticulous data scientist and enthusiastic team <br>player. Well -versed in statistical analysis techniques for insight derivation and <br>actively seeking opportunities to develop skills in machine learning. Eager to <br>continue growing in knowledge and applying skills to real -world problems, <br>especially in the health sector.  <br>EDUCATION  &amp; RELEVANT COURSEWORK  <br>Master of Data Science: Data Science   Sept  2024  – Sept  2026  <br>University of Guelph,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br> Continuing education in Machine Learning for Sequential Data <br>Processing, Analysis of Spatial -Temporal Data, Neural Networks,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Multi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  -<br>Agent Systems  <br>Data Scientist Associate Certification   Jan 2023 – Present   <br>DataCamp  <br> Received 1 -Year DataCamp  Scholarship worth $200 from Data
# Scientists Network (DSN).  <br> Completed professional development in Data Manipulation with <br>
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Data Visualization with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matplotlib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#   and
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seaborn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  , Joining Data <br>with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pandas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Programming , and Statistics in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  . <br> Continuing educatio n in EDA with
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Supervised learning with <br>
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scikit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  -learn, Unsupervised learning in P ython, Machine learning with <br>Tree -based models in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#   <br>Intro. to Software Project Management   Aug 2022 – Jan 2023  <br>Alison.com  <br> Completed  professional development in concepts and characteristics <br>of software management, activities involved in software project <br>management, Project management standards, Software life cycle <br>models, AGILE models.  <br>Telecommunication Engineering (B.Eng)  Nov. 2011 – April 2016  <br>Regent University College of Science and Technology,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ghana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br>(Second Class Upper)  <br> Continued  education in
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and MATLAB  <br>WORK HISTORY  <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Software Dev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  . Engineer / IT Support Specialist  May 2022 – Present  <br>NNPC ENSERV ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Port Harcourt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nigeria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   <br> Contributed ideas and suggestions in team meetings and delivered <br>updates on deadlines, designs, and enhancements.  <br> Discussed issues with team members to provide resolution and apply <br>best practices.  <br> Participated in software field testing to verify performance of developed <br>projects.  <br> Manages Linux storage systems (tape -based) for seismic data <br>processing, including maintaining storage environment and managing <br>backup activities.  <br>
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Supports
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and maintains
# <mark class="entity" style="background: orange; padding: 0.45em 0.6em;

# %% [markdown]
# ## **Match Score**
# To match resumes with company requirements and calculate a similarity score, we can use various methods such as TF-IDF, Word Embeddings (e.g., Word2Vec, GloVe), or BERT embeddings. Here, I'll demonstrate how to calculate the similarity score using TF-IDF (Term Frequency-Inverse Document Frequency) with cosine similarity.
#
# First, let's define the requirements of the company, and then we'll calculate the similarity score for each resume based on these requirements:
#
# * We define the company requirements as a string.
# * We clean the company requirements using the clean_text function we defined earlier.
# * We calculate the TF-IDF vectors for the company requirements and each resume text.
# * We calculate the cosine similarity between the TF-IDF vector of the company requirements and each resume.
# * We sort the indices of resumes based on the similarity scores in descending order.
# * We display the top N most similar resumes along with their similarity scores.
#
# You can adjust the value of top_n to display more or fewer similar resumes. Also, you can explore other similarity calculation methods and embeddings based on your preference and requirements.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Define the company requirements
company_requirements = "Data Scientist"

# Combine the company requirements with stopwords removed
cleaned_company_requirements = clean_text(company_requirements)
cleaned_company_requirements_str = ' '.join(cleaned_company_requirements)

# Calculate TF-IDF vectors for the company requirements and resume texts
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(data['resume_text'])
company_tfidf = tfidf_vectorizer.transform([cleaned_company_requirements_str])

# Calculate cosine similarity between the company requirements and each resume
similarity_scores = cosine_similarity(company_tfidf, tfidf_matrix).flatten()

# Get the indices of resumes sorted by similarity score
sorted_indices = similarity_scores.argsort()[::-1]

# Display the top 5 most similar resumes
top_n = 5
for i in range(top_n):
    index = sorted_indices[i]
    print(f"Resume ID: {data['ID'][index]}")
    print(f"Similarity Score: {similarity_scores[index]}")
    print(data['resume_text'][index])
    print()
# Out:
# Resume ID: 1
# Similarity Score: 0.25577110330302455
#
#
#
# CONTACT
# alfiinyang@gmail.com
# +234 708 005 5637
# Port Harcourt, Nigeria
# PROFILES /PORTFOLIOS
# • DataCamp
# • Medium
# • LinkedIn
# • Canva
#
# SKILLS
# • Python, C++ , Linux
# (CentOS7)
# • Graphic Design (Canva)
# • Public Speaking, Teaching,
# Technical Presentation
# • Excel, Power BI,
# PowerPoint
# • ETL, Data Visualization,
# (Matplotlib, Pandas,
# Numpy , Seaborn)
# • Workplace Psychological
# Safety, Cultural Intelligence ,
# Hypothesis based problem
# solving
# INTERESTS  & HOBBIES
# • Machine Learning and
# Genomics
# • Marvel Comics  by Comics
# Explained
# • Baseball 9
#  Ime Inyang
# Data Scientist
#
#
# SUMMARY
# Detail -oriented, organized and meticulous data scientist and enthusiastic team
# player. Well -versed in statistical analysis techniques for insight derivation and
# actively seeking opportunities to motivate others towards professional
# development . Eager to continue growing in knowledge and applying skills to
# real-world problems, especially in the health sector.
# EDUCATION  & RELEVANT COURSEWORK
# Master of Data Science: Data Science   Sept  2024  – Sept  2026
# University of Guelph, Canada
# • Continuing education in Machine Learning for Sequential Data
# Processing, Analysis of Spatial -Temporal Data, Neural Networks, Multi -
# Agent Systems
# Data Scientist Associate Certification   Jan 2023 – Present
# DataCamp
# • Completed professional development in Data Manipulation with
# Pandas, Data Visualization with Matplotlib  and Seaborn , Joining Data
# with Pandas, Python Programming , and Statistics in Python .
# • Continuing education in EDA with Python, Supervised learning with
# Scikit -learn, Unsupervised learning in P ython, Machine learning with
# Tree -based models in Python
# Intro. to Software Project Management   Aug 2022 – Jan 2023
# Alison.com
# • Completed professional development in concepts and characteristics
# of software management, activities involved in software project
# management, Project management standards, Software life cycle
# models, AGILE models.
# Telecommunication Engineering (B.Eng)  Nov. 2011 – April 2016
# Regent University College of Science and Technology, Ghana
# (Second Class Upper)
# • Continued  education in C++ and MATLAB
# WORK HISTORY
# IT Support Specialist /Software Dev. Engineer   May 2022 – Present
# NNPC ENSERV , Port Harcourt, Nigeria
# • Manages Linux storage systems (tape -based) for seismic data
# processing, including maintaining storage environment and
# managing backup activities.
# • Supports and maintains Linux systems , including tape drives,
# workstations,  and servers for seismic data processing , and systems
# network .
# • Participated in software field testing to verify performance of
# developed projects.
# Data Analyst       Feb 2023 – Present
# Maven Analytics: Hospital Consumer Assessment of Healthcare Providers and
# Systems (HCAHPS) data challenge
# • Employed Python to analyze and clean extensive HCAHPS data,
# reducing data redundancy by 25% and ensuring a more accurate
# representation.
#   • Developed and implemented key performance indicators, resulting in a 15% improvement in the identification
# of critical healthcare metrics.
# • Created visually compelling dashboards and reports, contributing to a 30% increase in data interpretation
# efficiency and facilitating more informed decision -making  using Seaborne .
# UmojaHack Africa 2023  Carbon Dioxide Prediction Challenge
# • Performed data importation, cleaning, and analysis for prediction model training  using Python, contributing
# to 270/ 441 placement on the leaderboard.
# Octave Data and Analytics: 20 Data Analytics Project
# • Performed consumer sentiment analysis on hotel data  using Power BI.
# Field Engineer           Apr 2018 – May 2022
# NNPC ENSERV, Port Harcourt, Nigeria
# • Installed and maintained communication equipment for remote field workers.
# • Maintained and repaired data acquisition instruments, including DT -HP305V geophones for seismic data
# acquisition in swampy terrain.
# • Prepared detailed reports and presentations (technical and non -technical) for project completion reporting.
# Mathematics Teacher           Dec 2016 – Oct 2017
# Institute of Qur’anic Studies, Funtua Nigeria
# • Provided meaningful math instruction to improve math skills of students at the junior high school level.
# • Mentored students individua lly to help improve math skills.
# • Employed  storytelling as a teaching technique to drive student engagement and improve communication
# and student understanding , resulting in  23% increase in student engagement .
#
# ACHIEVEMENTS
# • Awarded 1 -year DataCamp Scholarship by Data Scientists Network (DSN)
# • Taught introductory C++ to processing geophysicists using CodeBlocks IDE via Mi crosoft Teams. Topics
# included C++  anatomy, varables and constants, expressions and st atements, and loops. This contributed to
# NNPC -ENSERV  saving approximately $427 on introductory C++ training.
# • Completed McKinsey F orward Learners training on “Communicating for Impact”, resulting in increased
# personal and profession communication effectiveness by 15%.
# • Tutored in MATLAB laboratory classes for modelling and simulation of systems in 2015,  contribut ing to
# improvement of class average by 10%.
# • Conducted free mathematics extramural classes for interested students which helped increase their
# academic performance by 30%.
# • Researched and delivered technical presentation on “ Leveraging Technology to Create Efficency in Seismic
# Acquisition ” at NNPC ENSERV  using engaging infographics, resulting in 11% employee learning commitment .
# VOLUNTEERING ACTIVITIES
# • Hosted  anti-tribalism campai gns through Telegram under the name “ New Generation Nigeria National
# Intercessory Mission ”.
# • Conducted free extramural classes as a Mathematics teacher to help struggling students in Northern Nigeria.
# • Participated in NDLEA anti -drug -abuse campaigns.
# MEMBERSHIPS
# • Data Scientists Network (DSN)
# • Internet Society (ISOC)
# • Google Developer Group (GDG)
#
#
# Resume ID: 4
# Similarity Score: 0.20037028936270695
#
#
#   Ime Inyang Jr.
# Data Scientist  / Software Developer
#
#
# SUMMARY
# Detail -oriented, organized and meticulous data scientist and enthusiastic team
# player. Well -versed in statistical analysis techniques  for product  development
# and actively seeking opportunities to develop skills in machine learning. Eager
# to continue growing in knowledge and applying skills to real -world problems,
# especially in the food and  health industry .
# EDUCATION  & RELEVANT COURSEWORK
# Data Scientist Associate Certification                Jan 2023 – Present
# DataCamp
# • Received 1 -Year DataCamp Scholarship worth $200 from Data
# Scientists Network (DSN).
# • Completed professional development in Data Manipulation with
# Pandas, Data Visualization with Matplotlib, Joining Data with Pandas,
# Python Programming , and Statistics in Python .
# • Continuing education in Data Visualization with Seaborn, EDA with
# Python, Supervised learning with Scikit -learn, Unsupervised learning in
# python, Machine learning with Tree -based models in Python
# Intro. to Software Project Management   Aug 2022 – Jan 2023
# Alison.com
# • Completed professional development in concepts and characteristics
# of software management, activities involved in software project
# management, Project management standards, Software life cycle
# models, AGILE models.
# Telecommunication Engineering (B.Eng)                 Nov. 2011 – April 2016
# Regent University College of Science and Technology, Ghana
# (Second Class Upper)
# • Continued  education in C++ and MATLA B
# WORK HISTORY
# Software Dev . Engineer / IT Support Specialist  May 2022 – Present
# NNPC ENSERV , Port Harcourt, Nigeria
# • Contributed ideas and suggestions in team meetings and delivered
# updates on deadlines, designs, and enhancements.
# • Discussed issues with team members to provide resolution and apply
# best practices.
# • Participated in software field testing to verify performance of
# developed projects.
# • Manages Linux storage systems (tape -based) for seismic data
# processing, including maintaining storage environme nt and
# managing backup activities.
# • Supports and maintains Linux systems and servers for seismic data
# processing.
# Field Engineer       Apr 2018 – May 2022
# NNPC ENSERV, Port Harcourt, Nigeria
# • Worked flexible hours across night, weekend and holiday shifts.
# • Researched and delivered technical presentations on alternative
# support processes and technologies to aid cost -effective and high -
# quality data acquisition projects.  CONTACT
# alfiinyang@gmail.com
# +234 708 005 5637
# Port Harcourt, Nigeria
# PROFILES
# • datacamp.com/profile/alfiin
# yang
# • linkedin.com/in/ime -
# inyang -jr/
# • medium.com/@alfiinyang/
#
# SKILLS
# • Python, C++ , Linux
# (CentOS7)
# • Graphic Design (Canva)
# • Public Speaking, Teaching,
# Technical Presentation
# • Excel, Power BI,
# PowerPoint
# • ETL, Data Visualization,
# Matplotlib, Pandas, Numpy
# • Workplace Psychological
# Safety, Cultural Intelligence ,
# Hypothesis based problem
# solving
# HOBBIES & INTERESTS
# • Food and nutrition research
# • Health research
# • Machine Learning and
# Genomics
# • Marvel Comics  by Comics
# Explained
# • Baseball 9
#   • Installed and maintained communication equipment for remote field workers.
# • Maintained and repaired data acquisition instruments, including DT -HP305V
# geophones for seismic data acquisition in swampy terrain.
# Mathematics Teacher       Dec 2016 – Oct 2017
# Institute of Qur’anic Studies , Funtua Nigeria
# • Provided meaningful math instruction to improve math skills of children.
# • Assessed submitted class assignments, determined grades, and reviewed work with
# struggling students to boost success chance.
# • Administered assessments and standardized tests to evaluat e student progress.
# • Prepared and implemented lesson plans covering required course topics.
# • Mentored students on individual basis to help develop math skills.
# • Implemented storytelling as a teaching technique to drive student engagement and
# improve communica tion and student understanding.
# ACHIEVEMENTS
# • Published a Medium article on Fighting COVID -19 in 2023 using Machine Learning.
# • Ranked top 50th percentile  in Zindi’s UmojaHack Africa 2023 for Carbon Dioxide
# Prediction Challenge .
# • Awarded 1 -year DataCamp Schola rship by Data Scientists Network (DSN)
# • Saved my company approximately $427 on be ginner -level C++ training by teaching
# co-workers C++  as an IT Support staff .
# • Completed McKinsey Forward Learners training program  which included problem
# solving through hypothesis led approach.
# • Researched and delivered technical presentation on “ Leveraging Technology to
# Create Efficency in Seismic Acquisition ” at NNPC ENSERV.
# • Completed WHO course on “ Introduction to COVID -19: Methods for Detection,
# Prevention, Response an d Control ”
# • Designed and constructed a silent home security system to warn visually and
# acoustically impaired people using haptic technology (vibrators)
# • Highest graded student in MATLAB (94%)
# VOLUNTEERING ACTIVITIES
# • Hosts anti -tribalism campai gns through Te legram under the name “ New Generation
# Nigeria National Intercessory Mission ”.
# • Conducted free extramural classes as a Mathematics teacher to help struggling
# students in Northern Nigeria.
# • Participated in NDLEA anti -drug -abuse campaigns.
# MEMBERSHIPS
# • Data Scientists Network (DSN)
# • Internet Society (ISOC)
# • Google Developer Group (GDG)
#
#
# Resume ID: 5
# Similarity Score: 0.18814637884577745
#
#
#   Ime Inyang
# Data Scientist  / Graphic Designer
#
#
# SUMMARY
# Detail -oriented, organized and meticulous data scientist and enthusiastic team
# player. Well -versed in statistical analysis techniques for insight derivation and
# actively seeking opportunities to develop skills in machine learning. Eager to
# continue growing in knowledge and applying skills to real -world problems,
# especially in the health sector.
# EDUCATION  & RELEVANT COURSEWORK
# Master of Data Science: Data Science   Sept  2024  – Sept  2026
# University of Guelph, Canada
#  Continuing education in Machine Learning for Sequential Data
# Processing, Analysis of Spatial -Temporal Data, Neural Networks, Multi -
# Agent Systems
# Data Scientist Associate Certification   Jan 2023 – Present
# DataCamp
#  Received 1 -Year DataCamp  Scholarship worth $200 from Data
# Scientists Network (DSN).
#  Completed professional development in Data Manipulation with
# Pandas, Data Visualization with Matplotlib  and Seaborn , Joining Data
# with Pandas, Python Programming , and Statistics in Python .
#  Continuing educatio n in EDA with Python, Supervised learning with
# Scikit -learn, Unsupervised learning in P ython, Machine learning with
# Tree -based models in Python
# Intro. to Software Project Management   Aug 2022 – Jan 2023
# Alison.com
#  Completed  professional development in concepts and characteristics
# of software management, activities involved in software project
# management, Project management standards, Software life cycle
# models, AGILE models.
# Telecommunication Engineering (B.Eng)  Nov. 2011 – April 2016
# Regent University College of Science and Technology, Ghana
# (Second Class Upper)
#  Continued  education in C++ and MATLAB
# WORK HISTORY
# Software Dev . Engineer / IT Support Specialist  May 2022 – Present
# NNPC ENSERV , Port Harcourt, Nigeria
#  Contributed ideas and suggestions in team meetings and delivered
# updates on deadlines, designs, and enhancements.
#  Discussed issues with team members to provide resolution and apply
# best practices.
#  Participated in software field testing to verify performance of developed
# projects.
#  Manages Linux storage systems (tape -based) for seismic data
# processing, including maintaining storage environment and managing
# backup activities.
#  Supports and maintains Linux systems and servers for seismic data
# processing.  CONTACT
# alfiinyang@gmail.com
# +234 708 005 5637
# Port Harcourt, Nigeria
# PROFILES /PORTFOLIOS
#  DataCamp
#  Canva
#  LinkedIn
#  Medium
#
# SKILLS
#  Python, C++ , Linux (CentOS7)
#  Graphic Design (Canva)
#  Public Speaking, Teaching,
# Technical Presentation
#  Excel, Power BI, PowerPoint
#  ETL, Data Visualization,
# (Matplotlib, Pandas, Numpy ,
# Seaborn)
#  Workplace Psychological
# Safety, Cultural Intelligence ,
# Hypothesis based problem
# solving
# INTERESTS  & HOBBIES
#  Machine Learning and
# Genomics
#  Marvel Comics  by Comics
# Explained
#  Baseball 9
#   Graphic Designer  / Digital Service Support  (Freelance)      Nov 2021  – Oct 2022
#  Designed  clear and compelling  social media campaign  and online  market place  graphic  materials  for Small
# Business es and Not -For-Profit  organizations , including  logo s, thumbnails, and digital fliers  and posters  for
# educational and humanitarian  content s using Canva.  Design s contributed to an average of 21% increase in
# monthly  customer  engagement  across 3 organizations .
#  Wrote clear -communicating  content for social media engagement , resulting in 20%  increase  in conversions
# across 3 organizations .
#  Provided  customer support services, resolv ing payment  issues  for 1 organization .
# Field Engineer           Apr 2018 – May 2022
# NNPC ENSERV , Port Harcourt, Nigeria
#  Designed and applied engaging and compelling  company /employee /client  focused  infographic s in 2022  to
# effectively communicate  company values and business perspective  in tech nical and business  (non -technical)
# presentations , contributing to  10% increas e in management satisfaction , 3% increase in client acquisition ,
# and 12% increase in employee learning commitment . Choice tools included Canva and MS PowerPoint.
#  Prepared detailed reports and presentations  (technical  and non -technical)  for project completion reporting.
#  Installed and maintained communication equipment for remote field workers.
#  Maintained and repaired data acquisition instruments, including DT -HP305V geophones for seismic data
# acquisition in swampy terrain.
# Mathematics Teacher          Dec 2016 – Oct 2017
# Institute of Qur’anic Studies , Funtua Nigeria
#  Provided meaningful math instruction to improve math skills of children.
#  Assessed submitted class assignments, determined  grades, and reviewed work with struggling students to
# boost success chance.
#  Administered assessments and standardized tests to evaluate student progress.
#  Prepared and implemented lesson plans covering required course topics.
#  Mentored students on individual basis to help improve  math skills.
#  Implemented storytelling as a teaching technique to drive student engagement and improve communication
# and student understanding.
# ACHIEVEMENTS
#  Analyzed  and v isualized Hospital C onsumer Assessment o f Healthcare Providers and Systems (HCAHPS)  data
# for the American Hospit al Ass ociation (AHA) under Maven Analytics  using Python  (Aug – Sept 2023) .
#  Provided data analysis and visualization services  for 2 projects under Octave Dat a and Analytics using PowerBI
# (Feb – Apr 2023) .
#  Ranked 270/441 in Zindi’s UmojaHack Africa 2023 for Carbon Dioxide Prediction Challenge  (Mar 2023)
#  Awarded 1 -year DataCamp Scholarship by Data Scientists Network (DSN)
#  Saved my company approximately $427 on be ginner -level C++ training by teaching co -workers C++  as an IT
# Support staff .
#  Comp leted McKinsey Forward Learners training program
#  Researched and delivered technical presentation on “ Leveraging Technology to Create Efficency in Seismic
# Acquisition ” at NNPC ENSERV  using engaging infographics , resulting in 11% employee learning commitment .
#  Completed WHO course on “ Introduction to COVID -19: Methods for Detection,  Prevention, Response and
# Control ”
# VOLUNTEERING ACTIVITIES
#  Hosts anti -tribal ism campai gns through Telegram under the name “ New Generation Nigeria National
# Intercessory Mission ”.
#  Conducted free extramural classes as a Mathematics teacher to help struggling students in Northern Nigeria.
#  Participated in NDLEA anti -drug -abuse campaigns.
# MEMBERSHIPS
#  Data Scientists Network (DSN)
#  Internet Society (ISOC)
#  Google Developer Group (GDG)
#
#
# Resume ID: 2
# Similarity Score: 0.17132076336230542
# Ime Okon Inyang Jnr.
# +234 708 005 5637
# alfiinyang@gmail.com  | github.com/alfiinyang/
#
# Highlights of Qualifications
# • Bachelor of Engineering in Telecommunication Engineering
# • Experienced using Power BI for data modelling and visualization
# • Experienced using Python's  Numpy, Matplotlib, Pandas , and Dat etime  packages  for
# data analysis and machine learning preprocessing .
# • Programs proficiently  in C++.
# • Experienced using SQL to query databases (university level experience ).
# • Over 6 months’ experience in Linux systems and storage administration for seismic
# data processing.
# • Presentation, communication, and teaching skills practiced continuously through
# business k nowledge sharing (C++ training  and business bids ).
# • Problem -solving  and workplace psychological safety practice skills  gained through
# 2022 McKinsey Forward  training.
# Education
# Python for Data Science        Jan 2023 – Present
# DataCamp
# Diploma in Software Project Management     Aug 2022 – Present
# National Programme on Technology Enhanced Learning (NPTEL), India (Alison.com)
# Bachelor of Engineering  (Telecommunication  Engineering)  Nov. 2011 – April 2016
# Regent University College of Science and Technology, Ghana  (Second Class Upper)
# • Project Title : Design and Construction of a Silent Home Security System Using Haptic
# Technology ( 69% or B)
# Work Experience
# Software Development Engineer / IT Support     Jun 2022 – Present
# NNPC ENSERV  (formerly IDSL) , Eleme PetroChemica l, Eleme, Rivers, Nigeria
# • Test s seismic data processing modules for proprietary software .
# • Understudies  C++ source code for proprietary seismic data processing software.
# • Manage s Linux storage systems (tape -based) for seismic data processing , including
# maintaining storage environment and managing backup activities.
# • Support s and maintain s Linux systems  and servers  for seismic data processing ,
# • Monitors and reports equipment health using Excel Spreadsheet.
# • Maintain s LAN/WLAN services for internet connectivity.
# • Monitors equipment health and reports to Systems Engineer .
# Data Acquisition  Engineer        April 2018 – May 2022
# Integrated Data Services Ltd (IDSL),  36 Ogba Road, Ogogugbo,  Benin City, Edo, Nigeria
# • Utilized Excel to track and visualize  employee work progress.  • Conducted leakage and SMT tests on ground sensors (geophones) using voltmeters
# and SMT -300 devices to ascertain fit -for-purpose sensors.
# • Maintained and repaired data acqui sition instruments, including DT-HP305V
# geophones for seismic data acquisition in swampy terrain.
# • Installed and m aintained communication equipment for remote field workers .
# • Researched and d eliver ed technical presentations on alternative  support processes
# and technologies to aid  cost -effective  and high -quality  data acquisition projects.
# • Reported to Head of Engineering.
# Mathematics Teacher        Dec 2016 – Oct 2017
# Institute of Qur’anic Studies, Funtu a (formerly Imam Sc. & Arts Secondary School)
# • Prepared lecture notes according to outlined curriculum.
# • Conducted continuous assessment tests for students and delivered assignments.
# • Corrected student assignments.
# • Recorded marks and reported to Vice Principa l.
# • Conducted extra -moral classes to prepare Olympiad  mathematics candidates.
# Engineering Intern         Jul 2014 – Sept 2014
# Cross River Broadcasting Corp. (CRBC), Calabar, Cross River, Nigeria
# • Set up broadcasting equipment
# • Maintained operational equipment including analog televisions, and TV and Radio
# antennas.
# • Maintained electrical units, including repair and replacement of power sockets  and
# power adapters.
# • Reported to Engineering Manager
# Interests/Achievements/Awards
# • Awarded a 1-year DataCamp Free Learning Scholarship by Data Scientists  Network
# (DSN) .
# • Ranked 270/441 for Zindi's  UmojaHack Africa 2023 : Carbon Dioxide Prediction
# Challenge (Beginner)
# • Taught C++ to coworkers, saving the company approximately $ 427  on beginner -level
# training.
# • Complet ed 1 data analytics  project  for Octave Data & Analytics  using Power BI.
# • Developed an employee management system using C++.
# • Successfully designed and constructed a silent security alarm system to inform deaf
# and blind people of security breaches.
# Professional Development
# • Member of Google Developer Group (GDG)    2022 – Present
# • Member of Internet Society (ISOC)      2022 – Present
# • Member of Data Scientists Network/Data Science Nigeria (DSN)  2021 – Present
# Professional Affiliations
# • Nigeria Computer So ciety       (Pending)
# Training  and Certifications
# • McKinsey Forward 2022  References
# Available upon request
#
# Resume ID: 3
# Similarity Score: 0.008342531273267928
#
#  - 1 - IME OKON INYANG (JNR) 5 Ebo Road, off Airport Road, Benin City, Edo, Nigeria +234 708 005 5637 (Mobile), alfiinyang@gmail.com (e-mail)  _______________________________________________________________________ PERSONAL INFORMATION Marital Status:  Single Nationality:  Nigerian Date of Birth:  17th December 1993 Languages:  English, Ibibio, Efik  OBJECTIVES  • To support the transitioning of oil and gas related services originating in developing nations into first world markets through delivery of professional experience with safety consciousness, whilst adapting to new business systems and techniques.  • To provide professional training for the immediate generation of “interprofessional” and “transprofessional” oil and gas employees by organizing modular courses in related/experienced fields.  WORK EXPERIENCE Ministry of Science and Technology, Uyo, Akwa Ibom State, Nigeria Position: Attachee (Engineering)    (August – September 2013) Responsibilities: • Purchasing electrical supplies • Assistance with technical labour  Cross River Broadcasting Corp. (CRBC), Calabar, Cross River State, Nigeria Position: Attachee (Engineering)    (July – August 2014) Responsibilities: • Operational equipment maintenance and repair • Outside-Broadcast (O/B) equipment setup • Purchasing engineering supplies • Software usage assistance
#  - 2 - Imam Science and Arts Secondary School, Funtua, Katsina State, Nigeria Position: NYSC Corper (Mathematics Teacher)  (December 2016 – October 2017) Responsibilities: • Teaching Senior Secondary 1 (SS1) students Mathematics • Conducting Mathematics Continuous Assessment Tests and Final Examination for SS1 students • Representing Corp Members serving in the institution to the school’s management Achievements: • Conducted free holiday Mathematics classes for students (COWBELLPEDIA competition)  NDLEA/NYSC Drug Free Club, Funtua, Katsina State, Nigeria Position: General Secretary    (February — November 2017) Responsibilities: • Record keeping of every meeting or event, conducted or organized within or by the club. • Preparation and delivery of documents and letters. • Organizing meetings with interest persons for club advancement. • Purchase of items for club's Community Development Project. Achievement: • Encouraged intercultural and interreligious symbiosis through sports and games, and open-air events.  • Co-led community development project: contributed and sought funding for project, as well as purchased project completion items. o Developed system for increasing drug-abuse awareness using digital LED Display.   Nigeria Christian Corpers Fellowship (NCCF) Funtua Zone, Katsina Chapter Position: Zonal Evangelism Secretary  (February — November 2017) Responsibilities: • Provide spiritual and moral encouragement for Christian corpers within Funtua Zone Achievement: • Helped establish new subzones within Funtua Zone and reestablished defunct subzones.
#  - 3 -  Integrated Data Services Ltd. (IDSL), Benin, Edo State, Nigeria Position: Instrument Engineer   (April 2018 – October 2018) Responsibilities: • Maintenance of recording/acquisition equipment.  Position: Seismic Observer (Junior)    (October 2018 – January 2019) Responsibilities: • Line workers enrollment • Line workers job monitoring Achievements: • Developed swift process for staff monitoring and reporting using MS Excel and Word.  Position: Node-man (Offshore)    (January 2019 – December 2019) Responsibilities: • Retrieve and deploy ocean bottom nodes (OBN) • Back-deck housekeeping Achievements: • Developed toolbox checklist for back-deck operations  Position: Engineer     (January 2020 – Present) Responsibilities: • Maintain field equipment Achievements: • Conducted knowledge sharing/training sessions for new recruits  EDUCATIONAL HISTORY • Regent University College of Science and Technolgy (RUCST) Bachelor of Engineering in Applied Electronics and Systems Engineering (Telecomunication Option) (Second Class Upper – 2.1)               2016 • St. Brian’s Model College (SBMC), Uyo, Akwa Ibom State West African Senior School Certificate Examination (WASSCE)  2010 • MONEF Kiddies International Nursery and Primary School (MONEF)
#  - 4 - First School Leaving Certificate (FSLC)     2004  CERTIFICATES • National Youth Service Corps: Certificate of National Service (2017) • BOSIET with EBS (2019) • Safety Management in the Oil and Gas Industry • CA-EBS  AWARDS • National Drug Law Enforcement Agency: Eradication of Drug Abuse and Trafficking – Certificate of Community Development (Nov 2017) • IDSL/CNPC-BGP Port Harcourt Seismic Capacity Building Program: Seismic Recording Certificate of Merit (Jul 2018) • Shell Nigeria/IDSL/CNPC-BGP (REM AQARIUS): HSSE Certificate of Appreciation (Jun 2019)  RELEVANT SKILLS • Leadership   Teamwork   Networking • Presentation Skills  Public Speaking • Teaching   Workplace Safety • Financial Planning & Budgeting • Project Management  Team motivation • Task Analysis   Cultural Intelligence  COMPUTER LITERACY/ TECHNICAL EXPERTISE • Digital Marketing • Windows environment • Apple environment • Microsoft: Word, Excel, PowerPoint • OMNI 3D, MATLAB, PSpice  REFERENCES Available on request
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## **Skill Extractor Function**
# Let's create a Python function that extracts skills from a resume using the entity ruler, matches them with required skills, and generates a similarity score. Here's how you can do it:
# * We define a function calculate_similarity that takes the resume text and required skills as input.
# * We process the resume text with the spaCy model.
# * We extract skills from the resume by filtering entities with the label "SKILL" using list comprehension.
# * We calculate the number of matching skills between the resume and required skills.
# * We calculate the similarity score by dividing the number of matching skills by the maximum of the lengths of required skills and extracted skills.
# * Finally, we return the similarity score.
#
# This function allows hiring managers to input a resume text and required skills, and it outputs a similarity score based on the matching skills. You can use this function in a loop to process multiple resumes and filter candidates based on their similarity scores.

# %%
def calculate_similarity(resume_text, required_skills):
    # Process the resume text with the spaCy model
    doc = nlp(resume_text)

    # Extract skills from the resume using the entity ruler
    skills = [ent.text.lower() for ent in doc.ents if ent.label_ == "SKILL"]

    # Calculate the number of matching skills with required skills
    matching_skills = [skill for skill in skills if skill in required_skills]
    num_matching_skills = len(matching_skills)

    # Calculate the similarity score
    similarity_score = num_matching_skills / max(len(required_skills), len(skills))

    return similarity_score
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Example usage:
for text in data[['cleaned_resume']].itertuples(index = False):
  resume_text = str(text[0])
  print(resume_text)
  required_skills = ["matplotlib", "numpy", "pandas", "data visiualization", "seaborn"]
  similarity_score = calculate_similarity(resume_text, required_skills)
  print("Similarity Score:", similarity_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['contact', 'alfiinyanggmailcom', '234', '708', '005', '5637', 'port', 'harcourt', 'nigeria', 'profile', 'portfolio', 'datacamp', 'medium', 'linkedin', 'canva', 'skill', 'python', 'c', 'linux', 'centos7', 'graphic', 'design', 'canva', 'public', 'speaking', 'teaching', 'technical', 'presentation', 'excel', 'power', 'bi', 'powerpoint', 'etl', 'data', 'visualization', 'matplotlib', 'panda', 'numpy', 'seaborn', 'workplace', 'psychological', 'safety', 'cultural', 'intelligence', 'hypothesis', 'based', 'problem', 'solving', 'interest', 'hobby', 'machine', 'learning', 'genomics', 'marvel', 'comic', 'comic', 'explained', 'baseball', '9', 'ime', 'inyang', 'data', 'scientist', 'summary', 'detail', 'oriented', 'organized', 'meticulous', 'data', 'scientist', 'enthusiastic', 'team', 'player', 'well', 'versed', 'statistical', 'analysis', 'technique', 'insight', 'derivation', 'actively', 'seeking', 'opportunity', 'motivate', 'others', 'towards', 'professional', 'development', 'eager', 'continue', 'growing', 'knowledge', 'applying', 'skill', 'realworld', 'problem', 'especially', 'health', 'sector', 'education', 'relevant', 'coursework', 'master', 'data', 'science', 'data', 'science', 'sept', '2024', 'sept', '2026', 'university', 'guelph', 'canada', 'continuing', 'education', 'machine', 'learning', 'sequential', 'data', 'processing', 'analysis', 'spatial', 'temporal', 'data', 'neural', 'network', 'multi', 'agent', 'system', 'data', 'scientist', 'associate', 'certification', 'jan', '2023', 'present', 'datacamp', 'completed', 'professional', 'development', 'data', 'manipulation', 'panda', 'data', 'visualization', 'matplotlib', 'seaborn', 'joining', 'data', 'panda', 'python', 'programming', 'statistic', 'python', 'continuing', 'education', 'eda', 'python', 'supervised', 'learning', 'scikit', 'learn', 'unsupervised', 'learning', 'p', 'ython', 'machine', 'learning', 'tree', 'based', 'model', 'python', 'intro', 'software', 'project', 'management', 'aug', '2022', 'jan', '2023', 'alisoncom', 'completed', 'professional', 'development', 'concept', 'characteristic', 'software', 'management', 'activity', 'involved', 'software', 'project', 'management', 'project', 'management', 'standard', 'software', 'life', 'cycle', 'model', 'agile', 'model', 'telecommunication', 'engineering', 'beng', 'nov', '2011', 'april', '2016', 'regent', 'university', 'college', 'science', 'technology', 'ghana', 'second', 'class', 'upper', 'continued', 'education', 'c', 'matlab', 'work', 'history', 'support', 'specialist', 'software', 'dev', 'engineer', 'may', '2022', 'present', 'nnpc', 'enserv', 'port', 'harcourt', 'nigeria', 'manages', 'linux', 'storage', 'system', 'tape', 'based', 'seismic', 'data', 'processing', 'including', 'maintaining', 'storage', 'environment', 'managing', 'backup', 'activity', 'support', 'maintains', 'linux', 'system', 'including', 'tape', 'drive', 'workstation', 'server', 'seismic', 'data', 'processing', 'system', 'network', 'participated', 'software', 'field', 'testing', 'verify', 'performance', 'developed', 'project', 'data', 'analyst', 'feb', '2023', 'present', 'maven', 'analytics', 'hospital', 'consumer', 'assessment', 'healthcare', 'provider', 'system', 'hcahps', 'data', 'challenge', 'employed', 'python', 'analyze', 'clean', 'extensive', 'hcahps', 'data', 'reducing', 'data', 'redundancy', '25', 'ensuring', 'accurate', 'representation', 'developed', 'implemented', 'key', 'performance', 'indicator', 'resulting', '15', 'improvement', 'identification', 'critical', 'healthcare', 'metric', 'created', 'visually', 'compelling', 'dashboard', 'report', 'contributing', '30', 'increase', 'data', 'interpretation', 'efficiency', 'facilitating', 'informed', 'decision', 'making', 'using', 'seaborne', 'umojahack', 'africa', '2023', 'carbon', 'dioxide', 'prediction', 'challenge', 'performed', 'data', 'importation', 'cleaning', 'analysis', 'prediction', 'model', 'training', 'using', 'python', 'contributing', '270', '441', 'placement', 'leaderboard', 'octave', 'data', ' ...
# Similarity Score: 0.36363636363636365
# ['ime', 'okon', 'inyang', 'jnr', '234', '708', '005', '5637', 'alfiinyanggmailcom', 'githubcomalfiinyang', 'highlight', 'qualification', 'bachelor', 'engineering', 'telecommunication', 'engineering', 'experienced', 'using', 'power', 'bi', 'data', 'modelling', 'visualization', 'experienced', 'using', 'python', 'numpy', 'matplotlib', 'panda', 'dat', 'etime', 'package', 'data', 'analysis', 'machine', 'learning', 'preprocessing', 'program', 'proficiently', 'c', 'experienced', 'using', 'sql', 'query', 'database', 'university', 'level', 'experience', '6', 'month', 'experience', 'linux', 'system', 'storage', 'administration', 'seismic', 'data', 'processing', 'presentation', 'communication', 'teaching', 'skill', 'practiced', 'continuously', 'business', 'k', 'nowledge', 'sharing', 'c', 'training', 'business', 'bid', 'problem', 'solving', 'workplace', 'psychological', 'safety', 'practice', 'skill', 'gained', '2022', 'mckinsey', 'forward', 'training', 'education', 'python', 'data', 'science', 'jan', '2023', 'present', 'datacamp', 'diploma', 'software', 'project', 'management', 'aug', '2022', 'present', 'national', 'programme', 'technology', 'enhanced', 'learning', 'nptel', 'india', 'alisoncom', 'bachelor', 'engineering', 'telecommunication', 'engineering', 'nov', '2011', 'april', '2016', 'regent', 'university', 'college', 'science', 'technology', 'ghana', 'second', 'class', 'upper', 'project', 'title', 'design', 'construction', 'silent', 'home', 'security', 'system', 'using', 'haptic', 'technology', '69', 'b', 'work', 'experience', 'software', 'development', 'engineer', 'support', 'jun', '2022', 'present', 'nnpc', 'enserv', 'formerly', 'idsl', 'eleme', 'petrochemica', 'l', 'eleme', 'river', 'nigeria', 'test', 'seismic', 'data', 'processing', 'module', 'proprietary', 'software', 'understudy', 'c', 'source', 'code', 'proprietary', 'seismic', 'data', 'processing', 'software', 'manage', 'linux', 'storage', 'system', 'tape', 'based', 'seismic', 'data', 'processing', 'including', 'maintaining', 'storage', 'environment', 'managing', 'backup', 'activity', 'support', 'maintain', 'linux', 'system', 'server', 'seismic', 'data', 'processing', 'monitor', 'report', 'equipment', 'health', 'using', 'excel', 'spreadsheet', 'maintain', 'lanwlan', 'service', 'internet', 'connectivity', 'monitor', 'equipment', 'health', 'report', 'system', 'engineer', 'data', 'acquisition', 'engineer', 'april', '2018', 'may', '2022', 'integrated', 'data', 'service', 'ltd', 'idsl', '36', 'ogba', 'road', 'ogogugbo', 'benin', 'city', 'edo', 'nigeria', 'utilized', 'excel', 'track', 'visualize', 'employee', 'work', 'progress', 'conducted', 'leakage', 'smt', 'test', 'ground', 'sensor', 'geophones', 'using', 'voltmeter', 'smt', '300', 'device', 'ascertain', 'fit', 'forpurpose', 'sensor', 'maintained', 'repaired', 'data', 'acqui', 'sition', 'instrument', 'including', 'dthp305v', 'geophones', 'seismic', 'data', 'acquisition', 'swampy', 'terrain', 'installed', 'aintained', 'communication', 'equipment', 'remote', 'field', 'worker', 'researched', 'eliver', 'ed', 'technical', 'presentation', 'alternative', 'support', 'process', 'technology', 'aid', 'cost', 'effective', 'high', 'quality', 'data', 'acquisition', 'project', 'reported', 'head', 'engineering', 'mathematics', 'teacher', 'dec', '2016', 'oct', '2017', 'institute', 'quranic', 'study', 'funtu', 'formerly', 'imam', 'sc', 'art', 'secondary', 'school', 'prepared', 'lecture', 'note', 'according', 'outlined', 'curriculum', 'conducted', 'continuous', 'assessment', 'test', 'student', 'delivered', 'assignment', 'corrected', 'student', 'assignment', 'recorded', 'mark', 'reported', 'vice', 'principa', 'l', 'conducted', 'extra', 'moral', 'class', 'prepare', 'olympiad', 'mathematics', 'candidate', 'engineering', 'intern', 'jul', '2014', 'sept', '2014', 'cross', 'river', 'broadcasting', 'corp', 'crbc', 'calabar', 'cross', 'river', 'nigeria', 'set', 'broadcasting', 'equipment', 'maintained', 'operational', 'equipment', 'including', 'analog', ' ...
# Similarity Score: 0.2
# ['1', 'ime', 'okon', 'inyang', 'jnr', '5', 'ebo', 'road', 'airport', 'road', 'benin', 'city', 'edo', 'nigeria', '234', '708', '005', '5637', 'mobile', 'alfiinyanggmailcom', 'email', '_______________________________________________________________________', 'personal', 'information', 'marital', 'status', 'single', 'nationality', 'nigerian', 'date', 'birth', '17th', 'december', '1993', 'language', 'english', 'ibibio', 'efik', 'objective', 'support', 'transitioning', 'oil', 'gas', 'related', 'service', 'originating', 'developing', 'nation', 'first', 'world', 'market', 'delivery', 'professional', 'experience', 'safety', 'consciousness', 'whilst', 'adapting', 'new', 'business', 'system', 'technique', 'provide', 'professional', 'training', 'immediate', 'generation', 'interprofessional', 'transprofessional', 'oil', 'gas', 'employee', 'organizing', 'modular', 'course', 'relatedexperienced', 'field', 'work', 'experience', 'ministry', 'science', 'technology', 'uyo', 'akwa', 'ibom', 'state', 'nigeria', 'position', 'attachee', 'engineering', 'august', 'september', '2013', 'responsibility', 'purchasing', 'electrical', 'supply', 'assistance', 'technical', 'labour', 'cross', 'river', 'broadcasting', 'corp', 'crbc', 'calabar', 'cross', 'river', 'state', 'nigeria', 'position', 'attachee', 'engineering', 'july', 'august', '2014', 'responsibility', 'operational', 'equipment', 'maintenance', 'repair', 'outsidebroadcast', 'ob', 'equipment', 'setup', 'purchasing', 'engineering', 'supply', 'software', 'usage', 'assistance', '2', 'imam', 'science', 'art', 'secondary', 'school', 'funtua', 'katsina', 'state', 'nigeria', 'position', 'nysc', 'corper', 'mathematics', 'teacher', 'december', '2016', 'october', '2017', 'responsibility', 'teaching', 'senior', 'secondary', '1', 'ss1', 'student', 'mathematics', 'conducting', 'mathematics', 'continuous', 'assessment', 'test', 'final', 'examination', 'ss1', 'student', 'representing', 'corp', 'member', 'serving', 'institution', 'school', 'management', 'achievement', 'conducted', 'free', 'holiday', 'mathematics', 'class', 'student', 'cowbellpedia', 'competition', 'ndleanysc', 'drug', 'free', 'club', 'funtua', 'katsina', 'state', 'nigeria', 'position', 'general', 'secretary', 'february', 'november', '2017', 'responsibility', 'record', 'keeping', 'every', 'meeting', 'event', 'conducted', 'organized', 'within', 'club', 'preparation', 'delivery', 'document', 'letter', 'organizing', 'meeting', 'interest', 'person', 'club', 'advancement', 'purchase', 'item', 'club', 'community', 'development', 'project', 'achievement', 'encouraged', 'intercultural', 'interreligious', 'symbiosis', 'sport', 'game', 'openair', 'event', 'coled', 'community', 'development', 'project', 'contributed', 'sought', 'funding', 'project', 'well', 'purchased', 'project', 'completion', 'item', 'developed', 'system', 'increasing', 'drugabuse', 'awareness', 'using', 'digital', 'led', 'display', 'nigeria', 'christian', 'corpers', 'fellowship', 'nccf', 'funtua', 'zone', 'katsina', 'chapter', 'position', 'zonal', 'evangelism', 'secretary', 'february', 'november', '2017', 'responsibility', 'provide', 'spiritual', 'moral', 'encouragement', 'christian', 'corpers', 'within', 'funtua', 'zone', 'achievement', 'helped', 'establish', 'new', 'subzones', 'within', 'funtua', 'zone', 'reestablished', 'defunct', 'subzones', '3', 'integrated', 'data', 'service', 'ltd', 'idsl', 'benin', 'edo', 'state', 'nigeria', 'position', 'instrument', 'engineer', 'april', '2018', 'october', '2018', 'responsibility', 'maintenance', 'recordingacquisition', 'equipment', 'position', 'seismic', 'observer', 'junior', 'october', '2018', 'january', '2019', 'responsibility', 'line', 'worker', 'enrollment', 'line', 'worker', 'job', 'monitoring', 'achievement', 'developed', 'swift', 'process', 'staff', 'monitoring', 'reporting', 'using', 'excel', 'word', 'position', 'nodeman', 'offshore', 'january', '2019', 'december', '2019', 'responsibility', 'retrieve', 'deploy', 'ocean', 'bottom', 'node', 'o ...
# Similarity Score: 0.0
# ['ime', 'inyang', 'jr', 'data', 'scientist', 'software', 'developer', 'summary', 'detail', 'oriented', 'organized', 'meticulous', 'data', 'scientist', 'enthusiastic', 'team', 'player', 'well', 'versed', 'statistical', 'analysis', 'technique', 'product', 'development', 'actively', 'seeking', 'opportunity', 'develop', 'skill', 'machine', 'learning', 'eager', 'continue', 'growing', 'knowledge', 'applying', 'skill', 'real', 'world', 'problem', 'especially', 'food', 'health', 'industry', 'education', 'relevant', 'coursework', 'data', 'scientist', 'associate', 'certification', 'jan', '2023', 'present', 'datacamp', 'received', '1', 'year', 'datacamp', 'scholarship', 'worth', '200', 'data', 'scientist', 'network', 'dsn', 'completed', 'professional', 'development', 'data', 'manipulation', 'panda', 'data', 'visualization', 'matplotlib', 'joining', 'data', 'panda', 'python', 'programming', 'statistic', 'python', 'continuing', 'education', 'data', 'visualization', 'seaborn', 'eda', 'python', 'supervised', 'learning', 'scikit', 'learn', 'unsupervised', 'learning', 'python', 'machine', 'learning', 'tree', 'based', 'model', 'python', 'intro', 'software', 'project', 'management', 'aug', '2022', 'jan', '2023', 'alisoncom', 'completed', 'professional', 'development', 'concept', 'characteristic', 'software', 'management', 'activity', 'involved', 'software', 'project', 'management', 'project', 'management', 'standard', 'software', 'life', 'cycle', 'model', 'agile', 'model', 'telecommunication', 'engineering', 'beng', 'nov', '2011', 'april', '2016', 'regent', 'university', 'college', 'science', 'technology', 'ghana', 'second', 'class', 'upper', 'continued', 'education', 'c', 'matla', 'b', 'work', 'history', 'software', 'dev', 'engineer', 'support', 'specialist', 'may', '2022', 'present', 'nnpc', 'enserv', 'port', 'harcourt', 'nigeria', 'contributed', 'idea', 'suggestion', 'team', 'meeting', 'delivered', 'update', 'deadline', 'design', 'enhancement', 'discussed', 'issue', 'team', 'member', 'provide', 'resolution', 'apply', 'best', 'practice', 'participated', 'software', 'field', 'testing', 'verify', 'performance', 'developed', 'project', 'manages', 'linux', 'storage', 'system', 'tape', 'based', 'seismic', 'data', 'processing', 'including', 'maintaining', 'storage', 'environme', 'nt', 'managing', 'backup', 'activity', 'support', 'maintains', 'linux', 'system', 'server', 'seismic', 'data', 'processing', 'field', 'engineer', 'apr', '2018', 'may', '2022', 'nnpc', 'enserv', 'port', 'harcourt', 'nigeria', 'worked', 'flexible', 'hour', 'across', 'night', 'weekend', 'holiday', 'shift', 'researched', 'delivered', 'technical', 'presentation', 'alternative', 'support', 'process', 'technology', 'aid', 'cost', 'effective', 'high', 'quality', 'data', 'acquisition', 'project', 'contact', 'alfiinyanggmailcom', '234', '708', '005', '5637', 'port', 'harcourt', 'nigeria', 'profile', 'datacampcomprofilealfiin', 'yang', 'linkedincominime', 'inyang', 'jr', 'mediumcomalfiinyang', 'skill', 'python', 'c', 'linux', 'centos7', 'graphic', 'design', 'canva', 'public', 'speaking', 'teaching', 'technical', 'presentation', 'excel', 'power', 'bi', 'powerpoint', 'etl', 'data', 'visualization', 'matplotlib', 'panda', 'numpy', 'workplace', 'psychological', 'safety', 'cultural', 'intelligence', 'hypothesis', 'based', 'problem', 'solving', 'hobby', 'interest', 'food', 'nutrition', 'research', 'health', 'research', 'machine', 'learning', 'genomics', 'marvel', 'comic', 'comic', 'explained', 'baseball', '9', 'installed', 'maintained', 'communication', 'equipment', 'remote', 'field', 'worker', 'maintained', 'repaired', 'data', 'acquisition', 'instrument', 'including', 'dt', 'hp305v', 'geophones', 'seismic', 'data', 'acquisition', 'swampy', 'terrain', 'mathematics', 'teacher', 'dec', '2016', 'oct', '2017', 'institute', 'quranic', 'study', 'funtua', 'nigeria', 'provided', 'meaningful', 'math', 'instruction', 'improve', 'math', 'skill', 'child', 'assessed', 'submitted', 'class', 'assignment', ...
# Similarity Score: 0.3333333333333333
# ['ime', 'inyang', 'data', 'scientist', 'graphic', 'designer', 'summary', 'detail', 'oriented', 'organized', 'meticulous', 'data', 'scientist', 'enthusiastic', 'team', 'player', 'well', 'versed', 'statistical', 'analysis', 'technique', 'insight', 'derivation', 'actively', 'seeking', 'opportunity', 'develop', 'skill', 'machine', 'learning', 'eager', 'continue', 'growing', 'knowledge', 'applying', 'skill', 'real', 'world', 'problem', 'especially', 'health', 'sector', 'education', 'relevant', 'coursework', 'master', 'data', 'science', 'data', 'science', 'sept', '2024', 'sept', '2026', 'university', 'guelph', 'canada', 'continuing', 'education', 'machine', 'learning', 'sequential', 'data', 'processing', 'analysis', 'spatial', 'temporal', 'data', 'neural', 'network', 'multi', 'agent', 'system', 'data', 'scientist', 'associate', 'certification', 'jan', '2023', 'present', 'datacamp', 'received', '1', 'year', 'datacamp', 'scholarship', 'worth', '200', 'data', 'scientist', 'network', 'dsn', 'completed', 'professional', 'development', 'data', 'manipulation', 'panda', 'data', 'visualization', 'matplotlib', 'seaborn', 'joining', 'data', 'panda', 'python', 'programming', 'statistic', 'python', 'continuing', 'educatio', 'n', 'eda', 'python', 'supervised', 'learning', 'scikit', 'learn', 'unsupervised', 'learning', 'p', 'ython', 'machine', 'learning', 'tree', 'based', 'model', 'python', 'intro', 'software', 'project', 'management', 'aug', '2022', 'jan', '2023', 'alisoncom', 'completed', 'professional', 'development', 'concept', 'characteristic', 'software', 'management', 'activity', 'involved', 'software', 'project', 'management', 'project', 'management', 'standard', 'software', 'life', 'cycle', 'model', 'agile', 'model', 'telecommunication', 'engineering', 'beng', 'nov', '2011', 'april', '2016', 'regent', 'university', 'college', 'science', 'technology', 'ghana', 'second', 'class', 'upper', 'continued', 'education', 'c', 'matlab', 'work', 'history', 'software', 'dev', 'engineer', 'support', 'specialist', 'may', '2022', 'present', 'nnpc', 'enserv', 'port', 'harcourt', 'nigeria', 'contributed', 'idea', 'suggestion', 'team', 'meeting', 'delivered', 'update', 'deadline', 'design', 'enhancement', 'discussed', 'issue', 'team', 'member', 'provide', 'resolution', 'apply', 'best', 'practice', 'participated', 'software', 'field', 'testing', 'verify', 'performance', 'developed', 'project', 'manages', 'linux', 'storage', 'system', 'tape', 'based', 'seismic', 'data', 'processing', 'including', 'maintaining', 'storage', 'environment', 'managing', 'backup', 'activity', 'support', 'maintains', 'linux', 'system', 'server', 'seismic', 'data', 'processing', 'contact', 'alfiinyanggmailcom', '234', '708', '005', '5637', 'port', 'harcourt', 'nigeria', 'profile', 'portfolio', 'datacamp', 'canva', 'linkedin', 'medium', 'skill', 'python', 'c', 'linux', 'centos7', 'graphic', 'design', 'canva', 'public', 'speaking', 'teaching', 'technical', 'presentation', 'excel', 'power', 'bi', 'powerpoint', 'etl', 'data', 'visualization', 'matplotlib', 'panda', 'numpy', 'seaborn', 'workplace', 'psychological', 'safety', 'cultural', 'intelligence', 'hypothesis', 'based', 'problem', 'solving', 'interest', 'hobby', 'machine', 'learning', 'genomics', 'marvel', 'comic', 'comic', 'explained', 'baseball', '9', 'graphic', 'designer', 'digital', 'service', 'support', 'freelance', 'nov', '2021', 'oct', '2022', 'designed', 'clear', 'compelling', 'social', 'medium', 'campaign', 'online', 'market', 'place', 'graphic', 'material', 'small', 'business', 'e', 'forprofit', 'organization', 'including', 'logo', 'thumbnail', 'digital', 'flier', 'poster', 'educational', 'humanitarian', 'content', 'using', 'canva', 'design', 'contributed', 'average', '21', 'increase', 'monthly', 'customer', 'engagement', 'across', '3', 'organization', 'wrote', 'clear', 'communicating', 'content', 'social', 'medium', 'engagement', 'resulting', '20', 'increase', 'conversion', 'across', '3', 'organization', 'provided', 'cust ...
# Similarity Score: 0.4

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
